# %% [markdown]
# # Netflix Userbase Dataset
# ##### Sample Netflix User Data: Subscription Types, Revenue, User Details, and Activit
# The dataset provides a snapshot of a sample Netflix userbase, showcasing various aspects of user subscriptions, revenue, account details, and activity. Each row represents a unique user, identified by their User ID. The dataset includes information such as the user's subscription type (Basic, Standard, or Premium), the monthly revenue generated from their subscription, the date they joined Netflix (Join Date), the date of their last payment (Last Payment Date), and the country in which they are located.
#
# Additional columns have been included to provide insights into user behavior and preferences. These columns include Device Type (e.g., Smart TV, Mobile, Desktop, Tablet), Total Watch Time (in minutes), and Account Status (whether the account is active or not). The dataset serves as a synthetic representation and does not reflect actual Netflix user data. It can be used for analysis and modeling to understand user trends, preferences, and revenue generation within a hypothetical Netflix userbase.

# %% [markdown]
# ![dataset-cover.png](attachment:dataset-cover.png)

# %%
# Importing Library
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df=pd.read_csv('Netflix Userbase.csv')
df.head()
# Out:
#    User ID Subscription Type  Monthly Revenue Join Date Last Payment Date  \
# 0        1             Basic               10  15-01-22          10-06-23
# 1        2           Premium               15  05-09-21          22-06-23
# 2        3          Standard               12  28-02-23          27-06-23
# 3        4          Standard               12  10-07-22          26-06-23
# 4        5             Basic               10  01-05-23          28-06-23
#
#           Country  Age  Gender      Device Plan Duration
# 0   United States   28    Male  Smartphone       1 Month
# 1          Canada   35  Female      Tablet       1 Month
# 2  United Kingdom   42    Male    Smart TV       1 Month
# 3       Australia   51  Female      Laptop       1 Month
# 4         Germany   33    Male  Smartphone       1 Month

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2500 entries, 0 to 2499
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   User ID            2500 non-null   int64
#  1   Subscription Type  2500 non-null   object
#  2   Monthly Revenue    2500 non-null   int64
#  3   Join Date          2500 non-null   object
#  4   Last Payment Date  2500 non-null   object
#  5   Country            2500 non-null   object
#  6   Age                2500 non-null   int64
#  7   Gender             2500 non-null   object
#  8   Device             2500 non-null   object
#  9   Plan Duration      2500 non-null   object
# dtypes: int64(3), object(7)
# memory usage: 195.4+ KB

# %%
df.describe()
# Out:
#           User ID  Monthly Revenue          Age
# count  2500.00000      2500.000000  2500.000000
# mean   1250.50000        12.508400    38.795600
# std     721.83216         1.686851     7.171778
# min       1.00000        10.000000    26.000000
# 25%     625.75000        11.000000    32.000000
# 50%    1250.50000        12.000000    39.000000
# 75%    1875.25000        14.000000    45.000000
# max    2500.00000        15.000000    51.000000

# %%
for i in df:
    print(df[i].describe())
    print('-'*50)
# Out:
# count    2500.00000
# mean     1250.50000
# std       721.83216
# min         1.00000
# 25%       625.75000
# 50%      1250.50000
# 75%      1875.25000
# max      2500.00000
# Name: User ID, dtype: float64
# --------------------------------------------------
# count      2500
# unique        3
# top       Basic
# freq        999
# Name: Subscription Type, dtype: object
# --------------------------------------------------
# count    2500.000000
# mean       12.508400
# std         1.686851
# min        10.000000
# 25%        11.000000
# 50%        12.000000
# 75%        14.000000
# max        15.000000
# Name: Monthly Revenue, dtype: float64
# --------------------------------------------------
# count         2500
# unique         300
# top       05-11-22
# freq            33
# Name: Join Date, dtype: object
# --------------------------------------------------
# count         2500
# unique          26
# top       28-06-23
# freq           164
# Name: Last Payment Date, dtype: object
# ...

# %% [markdown]
# # Missing Value

# %%
df.isnull().sum()
# Out:
# User ID              0
# Subscription Type    0
# Monthly Revenue      0
# Join Date            0
# Last Payment Date    0
# Country              0
# Age                  0
# Gender               0
# Device               0
# Plan Duration        0
# dtype: int64

# %% [markdown]
# # Duplicate Value

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # User Id

# %%
df['User ID'].unique()
# Out:
# array([   1,    2,    3, ..., 2498, 2499, 2500], dtype=int64)

# %%
plt.figure(figsize=(12,6))
plt.subplot(2,2,1)
sns.kdeplot(x='User ID',data=df)
plt.subplot(2,2,2)
sns.boxplot(x='User ID',data=df)
plt.subplot(2,2,3)
sns.histplot(x='User ID',data=df)
plt.subplot(2,2,3)
sns.histplot(x='User ID',data=df)
plt.subplot(2,2,4)
sns.violinplot(x='User ID',data=df)
# Out:
# <Axes: xlabel='User ID'>

# %% [markdown]
# # Subscription Type

# %%
df['Subscription Type'].unique()
# Out:
# array(['Basic', 'Premium', 'Standard'], dtype=object)

# %% [markdown]
# ## Basic ---> 0
# ## Premium ---> 1
# ## Standard ---> 2

# %%
df['Subscription Type']=df['Subscription Type'].map({'Basic':0,'Premium':1,'Standard':2})

# %%
plt.figure(figsize=(10,6))
plt.subplot(2,2,1)
df['Subscription Type'].value_counts().plot(kind='bar',color=['red','green','blue'])
plt.subplot(2,2,2)
df['Subscription Type'].value_counts().plot(kind='pie',autopct='%1.f%%')
# Out:
# <Axes: ylabel='Subscription Type'>

# %% [markdown]
# ### Maximum User are from Basic Subscription rest Premium and Standard

# %% [markdown]
# # Monthly Revenue

# %%
df['Monthly Revenue'].describe()
# Out:
# count    2500.000000
# mean       12.508400
# std         1.686851
# min        10.000000
# 25%        11.000000
# 50%        12.000000
# 75%        14.000000
# max        15.000000
# Name: Monthly Revenue, dtype: float64

# %%
plt.figure(figsize=(10,6))
plt.subplot(2,2,1)
df['Monthly Revenue'].value_counts().sort_values(ascending=False).plot(kind='bar',color=['red','green','blue','pink','yellow','black'])
plt.subplot(2,2,2)
df['Monthly Revenue'].value_counts().sort_values(ascending=False).plot(kind='pie',autopct='%1.f%%')
# Out:
# <Axes: ylabel='Monthly Revenue'>

# %% [markdown]
# # Highest monthlt revenue earn is 12

# %%
plt.figure(figsize=(12,6))
plt.subplot(2,2,1)
sns.kdeplot(x='Monthly Revenue',data=df)
plt.subplot(2,2,2)
sns.boxplot(x='Monthly Revenue',data=df)
plt.subplot(2,2,3)
sns.histplot(x='Monthly Revenue',data=df)
plt.subplot(2,2,4)
sns.violinplot(x='Monthly Revenue',data=df)
# Out:
# <Axes: xlabel='Monthly Revenue'>

# %% [markdown]
# # Join Date

# %%
df['Join Date'].describe()
# Out:
# count         2500
# unique         300
# top       05-11-22
# freq            33
# Name: Join Date, dtype: object

# %%
df['Join Date']=pd.to_datetime(df['Join Date'])
df['Join Year']=df['Join Date'].dt.year
df['Join Month']=df['Join Date'].dt.month
df['Join Day']=df['Join Date'].dt.day

# %%
df.drop(columns=['Join Date'],axis=1,inplace=True)

# %%
plt.figure(figsize=(15,10))
plt.subplot(3,3,1)
sns.boxplot(x='Join Day',data=df)
plt.subplot(3,3,2)
sns.boxplot(x='Join Month',data=df)
plt.subplot(3,3,3)
sns.boxplot(x='Join Year',data=df)
plt.subplot(3,3,4)
sns.kdeplot(x='Join Day',data=df)
plt.subplot(3,3,5)
sns.kdeplot(x='Join Month',data=df)
plt.subplot(3,3,6)
sns.kdeplot(x='Join Year',data=df)
# Out:
# <Axes: xlabel='Join Year', ylabel='Density'>

# %%
# plt.figure(figsize=(15,10))
# plt.subplot(3,3,1)
# sns.lineplot(x='Join Day',y='User ID',data=df)
# plt.subplot(3,3,2)
# sns.lineplot(x='Join Month',y='User ID',data=df)
# plt.subplot(3,3,3)
# sns.lineplot(x='Join Year',y='User ID',data=df)

# %% [markdown]
# # Last Payment Date

# %%
df['Last Payment Date'].describe()
# Out:
# count         2500
# unique          26
# top       28-06-23
# freq           164
# Name: Last Payment Date, dtype: object

# %%
df['Last Payment Date']=pd.to_datetime(df['Last Payment Date'])
df['Last Payment Year']=df['Last Payment Date'].dt.year
df['Last Payment Month']=df['Last Payment Date'].dt.month
df['Last Payment Day']=df['Last Payment Date'].dt.day

# %%
df.drop(columns=['Last Payment Date'],axis=1,inplace=True)

# %%
df['Last Payment Year'].unique()
# Out:
# array([2023], dtype=int64)

# %%
# Analyzing Payement Monthly and Days
plt.figure(figsize=(10,5))
plt.subplot(2,2,1)
sns.boxplot(x='Last Payment Month',data=df)
plt.subplot(2,2,2)
sns.boxplot(x='Last Payment Day',data=df)
plt.subplot(2,2,3)
sns.kdeplot(x='Last Payment Month',data=df)
plt.subplot(2,2,4)
sns.kdeplot(x='Last Payment Day',data=df)
# Out:
# <Axes: xlabel='Last Payment Day', ylabel='Density'>

# %% [markdown]
# ### Payment mostly come in month April,May,June and July

# %%
plt.figure(figsize=(15,10))
plt.subplot(2,2,1)
df['Last Payment Month'].value_counts().sort_values(ascending=False).plot(kind='bar',color=['red','green','blue','pink','yellow','black'])
plt.subplot(2,2,2)
df['Last Payment Month'].value_counts().sort_values(ascending=False).plot(kind='pie',autopct='%1.f%%')
# Out:
# <Axes: ylabel='Last Payment Month'>

# %% [markdown]
# # Country

# %%
df['Country'].describe()
# Out:
# count              2500
# unique               10
# top       United States
# freq                451
# Name: Country, dtype: object

# %%
df['Country'].unique()
# Out:
# array(['United States', 'Canada', 'United Kingdom', 'Australia',
#        'Germany', 'France', 'Brazil', 'Mexico', 'Spain', 'Italy'],
#       dtype=object)

# %%
plt.figure(figsize=(15,10))
plt.subplot(2,2,1)
df['Country'].value_counts().plot(kind='bar',color=['red','green','blue','pink','yellow','black'])
plt.subplot(2,2,2)
df['Country'].value_counts().plot(kind='pie',autopct='%1.f%%')
# Out:
# <Axes: ylabel='Country'>

# %% [markdown]
# ### By data most users are from United States, Spain, Canada

# %%
df['Age'].describe()
# Out:
# count    2500.000000
# mean       38.795600
# std         7.171778
# min        26.000000
# 25%        32.000000
# 50%        39.000000
# 75%        45.000000
# max        51.000000
# Name: Age, dtype: float64

# %%
df['Age'].unique()
# Out:
# array([28, 35, 42, 51, 33, 29, 46, 39, 37, 44, 31, 45, 48, 27, 38, 36, 30,
#        43, 32, 41, 26, 34, 49, 40, 47, 50], dtype=int64)

# %%
plt.figure(figsize=(15,10))
plt.subplot(2,2,1)
df['Age'].value_counts().plot(kind='bar')
plt.subplot(2,2,2)
df['Age'].value_counts().plot(kind='pie',autopct='%1.f%%')
# Out:
# <Axes: ylabel='Age'>

# %% [markdown]
# ### Only age 26 has low users

# %% [markdown]
# # Age

# %%
print('Minimum Age Users:',df['Age'].min())
print('Maximum Age Users:',df['Age'].max())
# Out:
# Minimum Age Users: 26
# Maximum Age Users: 51

# %%
plt.figure(figsize=(15,10))
plt.subplot(3,3,1)
sns.boxplot(x='Age',data=df)
plt.subplot(3,3,2)
sns.kdeplot(x='Age',data=df)
plt.subplot(3,3,3)
sns.violinplot(x='Age',data=df)
# Out:
# <Axes: xlabel='Age'>

# %% [markdown]
# # Gender

# %%
df['Gender'].describe()
# Out:
# count       2500
# unique         2
# top       Female
# freq        1257
# Name: Gender, dtype: object

# %%
from sklearn import preprocessing
le = preprocessing.LabelEncoder()
le.fit(df['Gender'])
le.classes_
# Out:
# array(['Female', 'Male'], dtype=object)

# %%
df['Gender']=le.transform(df['Gender'])

# %% [markdown]
# ### 0 --> Female
# ### 1 --> Male

# %%
plt.figure(figsize=(15,10))
plt.subplot(2,2,1)
df['Gender'].value_counts().plot(kind='bar',color=['pink','blue'])
plt.subplot(2,2,2)
df['Gender'].value_counts().plot(kind='pie',autopct='%1.f%%')
# Out:
# <Axes: ylabel='Gender'>

# %% [markdown]
# # Device

# %%
df['Device'].unique()
# Out:
# array(['Smartphone', 'Tablet', 'Smart TV', 'Laptop'], dtype=object)

# %%
plt.figure(figsize=(15,10))
plt.subplot(2,2,1)
df['Device'].value_counts().plot(kind='bar',color=['red','green','blue','pink'])
plt.subplot(2,2,2)
df['Device'].value_counts().plot(kind='pie',autopct='%1.f%%')
# Out:
# <Axes: ylabel='Device'>

# %% [markdown]
# ### Smart TV is low not that much

# %% [markdown]
# # Plan Duration

# %%
df['Plan Duration'].describe()
# Out:
# count        2500
# unique          1
# top       1 Month
# freq         2500
# Name: Plan Duration, dtype: object

# %%
df['Plan Duration'].unique()
# Out:
# array(['1 Month'], dtype=object)

# %% [markdown]
# ### Data has only one month plan

# %%
df.to_csv('Netflix_analysis-2.csv')
